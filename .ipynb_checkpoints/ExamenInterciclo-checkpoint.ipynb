# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from sklearn.preprocessing import PolynomialFeatures
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
df = pd.read_csv('Covid-EC.csv', sep=',')

x = np.array(list(df.iloc[:, 0])) #dias
y = np.array(list(df.iloc[:, 6])) #recuperados

def reg_exponencial(x, c0, c1, c2, c3):
    return c0 * np.exp(-c1 * x) + c2 + c3

g = [100, 0.01, 200, 0.01]
pre = np.empty(len(y))
for i in range(len(y)):
    pre[i] = reg_exponencial(x[i], g[0], g[1], g[2], g[3])
    
popt, pcov = curve_fit(reg_exponencial, x, y, g)
for i in range(len(y)):
    pre[i] = reg_exponencial(x[i], popt[0], popt[1], popt[2], popt[3])
pp.plot(x, y)
pp.plot(x, pre, 'r*')

# %%
predi7 = np.array([i for i in range(len(x), len(x)+7)], dtype = float)
pp.plot(predi7, reg_exponencial(predi7, *popt), 'b*')
print('Prediccion 7 dias ', (int(reg_exponencial(predi7, *popt)[-1])), 'recuperados')
# Out:
# Prediccion 7 dias  5726 recuperados

# %%
predi30 = np.array([i for i in range(len(x), len(x)+31)], dtype = float)
pp.plot(predi30, reg_exponencial(predi30, *popt), 'b*')
print('Prediccion 30 dias ', (int(reg_exponencial(predi30, *popt)[-1])), 'recuperados')
# Out:
# Prediccion 30 dias  13675 recuperados

# %%
personas_teletrabajo = []
personas_presencial = []
personas_despedidas = []

# %%
class Persona:
    nombre = ''
    estado_trabajo = True
    tipo_trabajo = ''
    forma_trabajo = ''
    test = False
    
    def __init__(self, nombre, estado_trabajo, tipo_trabajo, forma_trabajo, test):
        self.nombre = nombre
        self.estado_trabajo = estado_trabajo
        self.tipo_trabajo = tipo_trabajo
        self.forma_trabajo = forma_trabajo
        self.test = test

# %%
class Simulacion:
    def __init__(self, env, estacion):
        self.env = env
        self.estacion = simpy.Resource(env, estacion)
    
    def notificacion_depidos(self, persona):
        posibilidad = random.randint(1, 7)
        if posibilidad > 7:
            persona.estado_trabajo = False
            print('Se ha notificado que a la persona ', persona.nombre, ' ha sido DESPEDIDA de su cargo')
            personas_despedidas.append(persona)
        else:
            print('Se ha notificado que a la persona ', persona.nombre, ' aun CONSERVA su cargo')
        yield self.env.timeout(1)
    
    def descanso_previo(self, persona):
        tiempo = random.randint(1, 7)
        yield self.env.timeout(tiempo)
        print('La persona', persona.nombre, ' descanso: ', tiempo, ' dias')
    def teletrabajo(self, persona):
        self.realizar_test(persona)
        if  persona.test == False:
            tiempo = random.randint(4, 15)
            yield self.env.timeout(tiempo)
            print('La persona', persona.nombre, ' empezo con el teletrabajo al dia: ',tiempo)
        else:
            tiempo = random.randint(4, 15)
            yield self.env.timeout(tiempo)
            print('La persona', persona.nombre, ' no paso el test de COVID CONTINUA con teletrabajo ',tiempo, 'dias mas')
    
    def realizar_test(self, persona):
        posibilidad = random.randint(0, 10) + 1
        if posibilidad < 8:
            persona.test = True
            personas_presencial.append(persona)
            print('La persona', persona.nombre, ' Retoma su trabajo normal en  el area de ', persona.tipo_trabajo)
        else:
            persona.test = False
            personas_teletrabajo.append(persona)

# %%
def simular(env, persona, simulacion):
    with simulacion.estacion.request() as estacion:
        yield estacion
        print('Notificacion estado de trabajo')
        yield env.process(simulacion.notificacion_depidos(persona))
        
    if persona.estado_trabajo:
        yield env.process(simulacion.descanso_previo(persona))
        yield env.process(simulacion.teletrabajo(persona))

# %%
def ejecutar_simulacion(env, estacion):
    simulacion = Simulacion(env, estacion)
    for persona in personas:
        yield env.timeout(1)
        env.process(simular(env, persona, simulacion))
env = simpy.Environment()
env.process(ejecutar_simulacion(env, 100))
env.run(until = 365)
# Out:
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(0)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(1)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(2)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(3)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(4)  aun CONSERVA su cargo
# La persona persona(0)  descanso:  4  dias
# La persona persona(3)  descanso:  1  dias
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(5)  aun CONSERVA su cargo
# La persona persona(2)  descanso:  3  dias
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(6)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(7)  aun CONSERVA su cargo
# La persona persona(1)  descanso:  6  dias
# La persona persona(1)  Retoma su trabajo normal en  el area de  viajes
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(8)  aun CONSERVA su cargo
# La persona persona(4)  descanso:  4  dias
# La persona persona(4)  Retoma su trabajo normal en  el area de  alimentacion
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(9)  aun CONSERVA su cargo
# La persona persona(8)  descanso:  1  dias
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(10)  aun CONSERVA su cargo
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(11)  aun CONSERVA su cargo
# La persona persona(5)  descanso:  6  dias
# La persona persona(5)  Retoma su trabajo normal en  el area de  hoteles
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(12)  aun CONSERVA su cargo
# La persona persona(11)  descanso:  1  dias
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(13)  aun CONSERVA su cargo
# La persona persona(6)  descanso:  7  dias
# La persona persona(7)  descanso:  6  dias
# La persona persona(7)  Retoma su trabajo normal en  el area de  alimentacion
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(14)  aun CONSERVA su cargo
# La persona persona(3)  empezo con el teletrabajo al dia:  10
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(15)  aun CONSERVA su cargo
# La persona persona(0)  empezo con el teletrabajo al dia:  11
# La persona persona(10)  descanso:  5  dias
# La persona persona(10)  Retoma su trabajo normal en  el area de  hoteles
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(16)  aun CONSERVA su cargo
# La persona persona(1)  no paso el test de COVID CONTINUA con teletrabajo  9 dias mas
# La persona persona(9)  descanso:  7  dias
# La persona persona(8)  empezo con el teletrabajo al dia:  7
# La persona persona(5)  no paso el test de COVID CONTINUA con teletrabajo  5 dias mas
# La persona persona(13)  descanso:  3  dias
# La persona persona(13)  Retoma su trabajo normal en  el area de  hoteles
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(17)  aun CONSERVA su cargo
# La persona persona(4)  no paso el test de COVID CONTINUA con teletrabajo  9 dias mas
# La persona persona(6)  empezo con el teletrabajo al dia:  4
# La persona persona(14)  descanso:  3  dias
# La persona persona(14)  Retoma su trabajo normal en  el area de  restaurante
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(18)  aun CONSERVA su cargo
# La persona persona(12)  descanso:  6  dias
# La persona persona(17)  descanso:  1  dias
# La persona persona(12)  Retoma su trabajo normal en  el area de  viajes
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(19)  aun CONSERVA su cargo
# La persona persona(17)  Retoma su trabajo normal en  el area de  retail
# La persona persona(2)  empezo con el teletrabajo al dia:  14
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(20)  aun CONSERVA su cargo
# La persona persona(7)  no paso el test de COVID CONTINUA con teletrabajo  7 dias mas
# La persona persona(15)  descanso:  5  dias
# La persona persona(9)  empezo con el teletrabajo al dia:  4
# La persona persona(15)  Retoma su trabajo normal en  el area de  retail
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(92)  aun CONSERVA su cargo
# La persona persona(85)  descanso:  7  dias
# La persona persona(91)  descanso:  1  dias
# La persona persona(85)  Retoma su trabajo normal en  el area de  alimentacion
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(93)  aun CONSERVA su cargo
# La persona persona(84)  no paso el test de COVID CONTINUA con teletrabajo  8 dias mas
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(94)  aun CONSERVA su cargo
# La persona persona(79)  no paso el test de COVID CONTINUA con teletrabajo  14 dias mas
# La persona persona(82)  empezo con el teletrabajo al dia:  11
# La persona persona(90)  descanso:  4  dias
# La persona persona(90)  Retoma su trabajo normal en  el area de  retail
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(95)  aun CONSERVA su cargo
# La persona persona(86)  empezo con el teletrabajo al dia:  8
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(96)  aun CONSERVA su cargo
# La persona persona(81)  no paso el test de COVID CONTINUA con teletrabajo  10 dias mas
# La persona persona(88)  empezo con el teletrabajo al dia:  7
# La persona persona(89)  empezo con el teletrabajo al dia:  5
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(97)  aun CONSERVA su cargo
# La persona persona(80)  no paso el test de COVID CONTINUA con teletrabajo  12 dias mas
# La persona persona(91)  empezo con el teletrabajo al dia:  5
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(98)  aun CONSERVA su cargo
# La persona persona(92)  descanso:  6  dias
# La persona persona(92)  Retoma su trabajo normal en  el area de  hoteles
# Notificacion estado de trabajo
# Se ha notificado que a la persona  persona(99)  aun CONSERVA su cargo
# La persona persona(95)  descanso:  4  dias
# La persona persona(96)  descanso:  3  dias
# La persona persona(95)  Retoma su trabajo normal en  el area de  viajes
# La persona persona(96)  Retoma su trabajo normal en  el area de  restaurante
# La persona persona(78)  empezo con el teletrabajo al dia:  15
# La persona persona(93)  descanso:  7  dias
# La persona persona(94)  descanso:  6  dias
# La persona persona(97)  descanso:  3  dias
# La persona persona(94)  Retoma su trabajo normal en  el area de  viajes
# La persona persona(97)  Retoma su trabajo normal en  el area de  viajes
# La persona persona(87)  empezo con el teletrabajo al dia:  13
# La persona persona(98)  descanso:  3  dias
# La persona persona(90)  no paso el test de COVID CONTINUA con teletrabajo  8 dias mas
# La persona persona(99)  descanso:  4  dias
# La persona persona(99)  Retoma su trabajo normal en  el area de  viajes
# La persona persona(96)  no paso el test de COVID CONTINUA con teletrabajo  5 dias mas
# La persona persona(85)  no paso el test de COVID CONTINUA con teletrabajo  15 dias mas
# La persona persona(97)  no paso el test de COVID CONTINUA con teletrabajo  8 dias mas
# La persona persona(94)  no paso el test de COVID CONTINUA con teletrabajo  9 dias mas
# La persona persona(92)  no paso el test de COVID CONTINUA con teletrabajo  12 dias mas
# La persona persona(95)  no paso el test de COVID CONTINUA con teletrabajo  12 dias mas
# La persona persona(98)  empezo con el teletrabajo al dia:  12
# La persona persona(93)  empezo con el teletrabajo al dia:  14
# La persona persona(99)  no paso el test de COVID CONTINUA con teletrabajo  15 dias mas

# %%
total_personas = 100
personas = []
#generar personas
for i in range(0, total_personas):
    persona = Persona('persona(%d)'%i, True, actividad(), 'teletrabajo', False)
    personas.append(persona)
    persona = None

# %%
def actividad():
    a = random.randint(0, 4)
    print(a)
    if a == 0:
        return 'alimentacion'
    if a == 1:
        return 'retail'
    if a == 2:
        return 'restaurante'
    if a == 3:
        return 'viajes'
    if a == 4:
        return 'hoteles'

# %%
actividad()
# Out:
# 'viajes'
